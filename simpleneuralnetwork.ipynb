# %% [markdown]
# <a href="https://colab.research.google.com/github/msravanthi19/Chatbot/blob/main/simpleneuralnetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

# %%
model=nn.Sequential(
    nn.Linear(2,4),
    nn.ReLU(),
    nn.Linear(4,1)
)

# %% [markdown]
# *   X contains input features
# *   y contains expected outputs

# %%
import torch
x=torch.tensor([[0.,0.],[0.,1.],[1.,0.],[1.,1.]])
y=torch.tensor([[0.],[1.],[1.],[0.]])

# %% [markdown]
#   Loss Function and Optimizer
#
#
# * MSELoss measures prediction error
# * Adam optimizer updates weights efficently

# %%
loss_fn=nn.MSELoss()
opt = torch.optim.Adam(model.parameters(),lr=0.01)

# %%
for i in range(1000):
  opt.zero_grad()
  loss=loss_fn(model(x),y)
  loss.backward()
  opt.step()

# %% [markdown]
# Model Inference
#
# printing the model's predictions after training

# %%
print(model(x))
# Out:
# tensor([[0.5000],
#         [0.5000],
#         [0.5000],
#         [0.5000]], grad_fn=<AddmmBackward0>)

# %%
# !pip install google-genai

# %%
from google import genai

# %%
client = genai.Client(api_key='AIzaSyC36eBei-Ubz9KPcFJ955nTqtVGAmTmG9s')
